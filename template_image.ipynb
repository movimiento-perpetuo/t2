# %% [markdown]
# # **<center>Transition to turbulence</center>**
#
# ### **<center> Daniel Olvera </center>**
#
# #### _<center> Seminar talk <br> date </center>_

# %% [markdown]
# <h3>Stratified plane Couette flow </h3>
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# # Stratified plane Couette flow
#
# ***
#
#
# <center> <img src="couette.png" width="300"/> </center>

# %% [markdown]
# <img src="./couette.png" alt="A" title="Title text" />

# %%
from IPython.display import Image
from IPython.core.display import HTML
PATH = "./images/"
Image(filename = PATH + "couette.png", width=300)

# %%
Image(filename = PATH + "couette.png", width=300)

# %%
from IPython.display import IFrame, display
#filepath = "http://wikipedia.org" # works with websites too!
filepath = "./images/COUETTE.pdf"
IFrame(filepath, width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="./images/COUETTE.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame(filepath, width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="./images/COUETTE.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
print('hello again')

# %%
print('more')

# %% [markdown]
# ## more text

# %% [markdown]
# # final

# %%
print('end')
